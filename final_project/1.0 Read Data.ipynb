# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import os

# %matplotlib inline

# %%
import zipfile

# %%
print(pd.__version__)
print(np.__version__)
print(matplotlib.__version__)
# Out:
# 1.0.1
# 1.18.1
# 3.1.3

# %%
pd.options.display.float_format = '{:20,.2f}'.format

# %% [markdown]
# ### Set zipfile reader

# %%
# https://stackoverflow.com/questions/26942476/reading-csv-zipped-files-in-python
zf = zipfile.ZipFile('competitive-data-science-predict-future-sales.zip')

# %% [markdown]
# ### Read and quick review items dataset

# %%
items = pd.read_csv(zf.open('items.csv'))
items
# Out:
#                                                item_name  item_id  \
# 0              ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1      !ABBYY FineReader 12 Professional Edition Full...        1
# 2          ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3        ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4            ***КОРОБКА (СТЕКЛО)                       D        4
# ...                                                  ...      ...
# 22165             Ядерный титбит 2 [PC, Цифровая версия]    22165
# 22166    Язык запросов 1С:Предприятия  [Цифровая версия]    22166
# 22167  Язык запросов 1С:Предприятия 8 (+CD). Хрустале...    22167
# 22168                                Яйцо для Little Inu    22168
# 22169                      Яйцо дракона (Игра престолов)    22169
#
#        item_category_id
# 0                    40
# 1                    76
# 2                    40
# 3                    40
# 4                    40
# ...

# %%
items.nunique()
# Out:
# item_name           22170
# item_id             22170
# item_category_id       84
# dtype: int64

# %%
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22170 entries, 0 to 22169
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   item_name         22170 non-null  object
#  1   item_id           22170 non-null  int64
#  2   item_category_id  22170 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 519.7+ KB

# %%
items.describe()
# Out:
#                    item_id     item_category_id
# count            22,170.00            22,170.00
# mean             11,084.50                46.29
# std               6,400.07                15.94
# min                   0.00                 0.00
# 25%               5,542.25                37.00
# 50%              11,084.50                40.00
# 75%              16,626.75                58.00
# max              22,169.00                83.00

# %% [markdown]
# ### Read and quick review sales_train dataset

# %%
sales_train = pd.read_csv(zf.open('sales_train.csv'))
sales_train['date'] = pd.to_datetime(sales_train['date'], format= '%d.%m.%Y')
sales_train['revenue'] = sales_train['item_price']*sales_train['item_cnt_day']
sales_train
# Out:
#               date  date_block_num  shop_id  item_id           item_price  \
# 0       2013-01-02               0       59    22154               999.00
# 1       2013-01-03               0       25     2552               899.00
# 2       2013-01-05               0       25     2552               899.00
# 3       2013-01-06               0       25     2554             1,709.05
# 4       2013-01-15               0       25     2555             1,099.00
# ...            ...             ...      ...      ...                  ...
# 2935844 2015-10-10              33       25     7409               299.00
# 2935845 2015-10-09              33       25     7460               299.00
# 2935846 2015-10-14              33       25     7459               349.00
# 2935847 2015-10-22              33       25     7440               299.00
# 2935848 2015-10-03              33       25     7460               299.00
#
#                 item_cnt_day              revenue
# ...

# %%
sales_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            datetime64[ns]
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
#  6   revenue         float64
# dtypes: datetime64[ns](1), float64(3), int64(3)
# memory usage: 156.8 MB

# %%
sales_train.nunique()
# Out:
# date               1034
# date_block_num       34
# shop_id              60
# item_id           21807
# item_price        19993
# item_cnt_day        198
# revenue           24775
# dtype: int64

# %%
sales_train.describe().T
# Out:
#                               count                 mean                  std  \
# date_block_num         2,935,849.00                14.57                 9.42
# shop_id                2,935,849.00                33.00                16.23
# item_id                2,935,849.00            10,197.23             6,324.30
# item_price             2,935,849.00               890.85             1,729.80
# item_cnt_day           2,935,849.00                 1.24                 2.62
# revenue                2,935,849.00             1,157.73             5,683.60
#
#                                 min                  25%                  50%  \
# date_block_num                 0.00                 7.00                14.00
# shop_id                        0.00                22.00                31.00
# item_id                        0.00             4,476.00             9,343.00
# item_price                    -1.00               249.00               399.00
# ...

# %%
sales_train[sales_train['item_price']==-1]
# Out:
#              date  date_block_num  shop_id  item_id           item_price  \
# 484683 2013-05-15               4       32     2973                -1.00
#
#                item_cnt_day              revenue
# 484683                 1.00                -1.00

# %%
sales_train[sales_train['item_price']==307980]
# Out:
#               date  date_block_num  shop_id  item_id           item_price  \
# 1163158 2013-12-13              11       12     6066           307,980.00
#
#                 item_cnt_day              revenue
# 1163158                 1.00           307,980.00

# %%
sales_train[sales_train['item_id']==6066]
# Out:
#               date  date_block_num  shop_id  item_id           item_price  \
# 1163158 2013-12-13              11       12     6066           307,980.00
#
#                 item_cnt_day              revenue
# 1163158                 1.00           307,980.00

# %%
sales_train[sales_train['item_id']==2973]
# Out:
#               date  date_block_num  shop_id  item_id           item_price  \
# 352     2013-01-15               0       25     2973             2,499.00
# 353     2013-01-16               0       25     2973             2,499.00
# 354     2013-01-17               0       25     2973             2,499.00
# 355     2013-01-18               0       25     2973             2,499.00
# 356     2013-01-19               0       25     2973             2,499.00
# ...            ...             ...      ...      ...                  ...
# 1765321 2014-06-22              17       57     2973             1,249.50
# 1782298 2014-06-09              17       47     2973             1,249.00
# 1851765 2014-07-04              18       26     2973             1,249.50
# 1923837 2014-08-06              19        6     2973             1,249.50
# 2131937 2014-11-20              22       51     2973             1,832.37
#
#                 item_cnt_day              revenue
# ...

# %% [markdown]
# ### Read and quick review item_categories dataset

# %%
item_categories = pd.read_csv(zf.open('item_categories.csv'))
item_categories
# Out:
#            item_category_name  item_category_id
# 0     PC - Гарнитуры/Наушники                 0
# 1            Аксессуары - PS2                 1
# 2            Аксессуары - PS3                 2
# 3            Аксессуары - PS4                 3
# 4            Аксессуары - PSP                 4
# ..                        ...               ...
# 79                  Служебные                79
# 80         Служебные - Билеты                80
# 81    Чистые носители (шпиль)                81
# 82  Чистые носители (штучные)                82
# 83           Элементы питания                83
#
# [84 rows x 2 columns]

# %%
item_categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   item_category_name  84 non-null     object
#  1   item_category_id    84 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.4+ KB

# %%
item_categories.nunique()
# Out:
# item_category_name    84
# item_category_id      84
# dtype: int64

# %%
item_categories.describe()
# Out:
#           item_category_id
# count                84.00
# mean                 41.50
# std                  24.39
# min                   0.00
# 25%                  20.75
# 50%                  41.50
# 75%                  62.25
# max                  83.00

# %% [markdown]
# ### Read and quick review shops dataset

# %%
shops = pd.read_csv(zf.open('shops.csv'))
shops
# Out:
#                                           shop_name  shop_id
# 0                     !Якутск Орджоникидзе, 56 фран        0
# 1                     !Якутск ТЦ "Центральный" фран        1
# 2                                  Адыгея ТЦ "Мега"        2
# 3                    Балашиха ТРК "Октябрь-Киномир"        3
# 4                          Волжский ТЦ "Волга Молл"        4
# 5                            Вологда ТРЦ "Мармелад"        5
# 6                        Воронеж (Плехановская, 13)        6
# 7                            Воронеж ТРЦ "Максимир"        7
# 8                      Воронеж ТРЦ Сити-Парк "Град"        8
# 9                                 Выездная Торговля        9
# 10                       Жуковский ул. Чкалова 39м?       10
# 11                       Жуковский ул. Чкалова 39м²       11
# 12                              Интернет-магазин ЧС       12
# 13                              Казань ТЦ "Бехетле"       13
# ...

# %%
shops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   shop_name  60 non-null     object
#  1   shop_id    60 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB

# %%
shops.nunique()
# Out:
# shop_name    60
# shop_id      60
# dtype: int64

# %%
shops.describe()
# Out:
#                    shop_id
# count                60.00
# mean                 29.50
# std                  17.46
# min                   0.00
# 25%                  14.75
# 50%                  29.50
# 75%                  44.25
# max                  59.00

# %% [markdown]
# ### Read and quick review test dataset

# %%
test = pd.read_csv(zf.open('test.csv'))
test
# Out:
#             ID  shop_id  item_id
# 0            0        5     5037
# 1            1        5     5320
# 2            2        5     5233
# 3            3        5     5232
# 4            4        5     5268
# ...        ...      ...      ...
# 214195  214195       45    18454
# 214196  214196       45    16188
# 214197  214197       45    15757
# 214198  214198       45    19648
# 214199  214199       45      969
#
# [214200 rows x 3 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214200 entries, 0 to 214199
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   ID       214200 non-null  int64
#  1   shop_id  214200 non-null  int64
#  2   item_id  214200 non-null  int64
# dtypes: int64(3)
# memory usage: 4.9 MB

# %%
test.nunique()
# Out:
# ID         214200
# shop_id        42
# item_id      5100
# dtype: int64

# %%
test.describe()
# Out:
#                         ID              shop_id              item_id
# count           214,200.00           214,200.00           214,200.00
# mean            107,099.50                31.64            11,019.40
# std              61,834.36                17.56             6,252.64
# min                   0.00                 2.00                30.00
# 25%              53,549.75                16.00             5,381.50
# 50%             107,099.50                34.50            11,203.00
# 75%             160,649.25                47.00            16,071.50
# max             214,199.00                59.00            22,167.00

# %% [markdown]
# ### Read and quick review sample_submission dataset

# %%
sample_submission = pd.read_csv(zf.open('sample_submission.csv'))
sample_submission
# Out:
#             ID       item_cnt_month
# 0            0                 0.50
# 1            1                 0.50
# 2            2                 0.50
# 3            3                 0.50
# 4            4                 0.50
# ...        ...                  ...
# 214195  214195                 0.50
# 214196  214196                 0.50
# 214197  214197                 0.50
# 214198  214198                 0.50
# 214199  214199                 0.50
#
# [214200 rows x 2 columns]

# %%
sample_submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214200 entries, 0 to 214199
# Data columns (total 2 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ID              214200 non-null  int64
#  1   item_cnt_month  214200 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 3.3 MB

# %%
sample_submission.nunique()
# Out:
# ID                214200
# item_cnt_month         1
# dtype: int64

# %%
sample_submission.describe()
# Out:
#                         ID       item_cnt_month
# count           214,200.00           214,200.00
# mean            107,099.50                 0.50
# std              61,834.36                 0.00
# min                   0.00                 0.50
# 25%              53,549.75                 0.50
# 50%             107,099.50                 0.50
# 75%             160,649.25                 0.50
# max             214,199.00                 0.50
